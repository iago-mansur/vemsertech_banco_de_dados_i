# %% [markdown]
# # Aula 6: Estruturação do banco e JOIN us ON su.c = e.sso;

# %% [markdown]
# ## PROJETO
#
# - Duplinha ou não;
# - Escolha um dataset de sua preferência (Kaggle, UCI,...);
# - https://www.kaggle.com/datasets;
# - https://archive.ics.uci.edu/datasets;
# - Coloque-o no postgres (hmmmm... como? ...);
# - Usando o Jupyter notebook, faça uma análise descritiva;
#     - Qual as tipagens das colunas?;
#     - Quantos nulos temos em cada coluna?;
#     - Quantos valores únicos temos nas colunas categoricas?;
#     - ...;
# - Ainda no Jupyter, faça 10 perguntas ao seu dataset e responda-as com querys;
#     - Qual o top 10 vendas?;
#     - Qual o top 5 clientes?;
#     - Qual medida é minoria?;
#     - ...;
# - Organize tudo em um HTML e entregue este relatório;
# - Entrega até 15/12 as 23h59 (OS DOIS DA DUPLA DEVEM ME ENVIAR)
# - r.otavioms@gmail.com

# %% [markdown]
# # Integridade entre as tabelas:
#
# - PRIMARY KEY;
# - FOREIGN KEY;
# - ON UPDATE CASCADE;
# - ON DELETE CASCADE;

# %% [markdown]
# # Agora sim podemos criar toda a base com o arquivo comandos_postgre.sql

# %%
from sqlalchemy import create_engine
import pandas as pd

# SGBD://USER:SENHA@HOST/DATABASE

engine = create_engine('postgresql+psycopg2://postgres:senha@localhost/postgres')
conn = engine.connect()

# %%
# Conecte o curso a tabela de transações
query = "SELECT * FROM ada.transacoes"

pd.read_sql_query(query, con = conn)
# Out:
#     id_transacao  id_aluno  id_curso  id_vendedor  id_pagamento
# 0              1         1         1            1             1
# 1              2         2         1            2             2
# 2              3         3         1            1             2
# 3              4         4         1            2             1
# 4              5         5         1            1             3
# 5              6         6         1            1             3
# 6              7         7         1            2             1
# 7              8         8         1            2             1
# 8              9         9         2            1             4
# 9             10        10         2            2             4
# 10            11        11         2            2             2
# 11            12        12         2            2             1
# 12            13        13         2            2             1
# 13            14        14         2            1             1
# 14            15        15         2            1             5
# 15            16        16         2            1             2
# 16            17        17         2            1             2
# 17            18        18         2            3             3
# 18            19        19         2            3             5
# 19            20        20         2            3             3
# 20            21        21         2            1             1
# 21            22        22         3            3             5
# 22            23        23         3            3             5
# 23            24        24         3            3             4
# 24            25        25         3            3             4
# 25            26        26         3            1             5
# 26            27        27         3            1             2
# 27            28        28         3            1             2
# 28            29        29         3            1             5
# 29            30        30         4            2             5
# 30            31        31         4            2             2
# 31            32        32         4            2             2
# 32            33        33         4            2             2
# 33            34        34         4            2             5

# %%
# Conecte o curso a tabela de transações
query = "SELECT * FROM ada.vendedores"

pd.read_sql_query(query, con = conn)
# Out:
#    id_vendedor vendedor
# 0            1    paulo
# 1            2  adriana
# 2            3    nadir

# %%
# conectem a tabela de transações com a tabela de vendedores
query = """
SELECT 
    *
FROM 
ada.transacoes AS t
LEFT JOIN ada.vendedores AS v ON t.id_vendedor = v.id_vendedor
"""

pd.read_sql_query(query, con = conn)
# Out:
#     id_transacao  id_aluno  id_curso  id_vendedor  id_pagamento  id_vendedor  \
# 0              1         1         1            1             1            1
# 1              2         2         1            2             2            2
# 2              3         3         1            1             2            1
# 3              4         4         1            2             1            2
# 4              5         5         1            1             3            1
# 5              6         6         1            1             3            1
# 6              7         7         1            2             1            2
# 7              8         8         1            2             1            2
# 8              9         9         2            1             4            1
# 9             10        10         2            2             4            2
# 10            11        11         2            2             2            2
# 11            12        12         2            2             1            2
# 12            13        13         2            2             1            2
# 13            14        14         2            1             1            1
# 14            15        15         2            1             5            1
# 15            16        16         2            1             2            1
# 16            17        17         2            1             2            1
# 17            18        18         2            3             3            3
# 18            19        19         2            3             5            3
# 19            20        20         2            3             3            3
# 20            21        21         2            1             1            1
# 21            22        22         3            3             5            3
# 22            23        23         3            3             5            3
# 23            24        24         3            3             4            3
# 24            25        25         3            3             4            3
# 25            26        26         3            1             5            1
# 26            27        27         3            1             2            1
# 27            28        28         3            1             2            1
# 28            29        29         3            1             5            1
# 29            30        30         4            2             5            2
# 30            31        31         4            2             2            2
# 31            32        32         4            2             2            2
# 32            33        33         4            2             2            2
# 33            34        34         4            2             5            2
#
#    vendedor
# 0     paulo
# 1   adriana
# 2     paulo
# 3   adriana
# 4     paulo
# 5     paulo
# 6   adriana
# 7   adriana
# 8     paulo
# 9   adriana
# 10  adriana
# 11  adriana
# 12  adriana
# 13    paulo
# 14    paulo
# 15    paulo
# 16    paulo
# 17    nadir
# 18    nadir
# 19    nadir
# 20    paulo
# 21    nadir
# 22    nadir
# 23    nadir
# 24    nadir
# 25    paulo
# 26    paulo
# 27    paulo
# 28    paulo
# 29  adriana
# 30  adriana
# 31  adriana
# 32  adriana
# 33  adriana

# %% [markdown]
# ## Bem vindo ao GROUP BY
#
# GROUP BY
#
# Funções possíveis:
#
# - SUM(nome_coluna) -> Soma dos valores
# - AVG(nome_coluna) -> Média dos valores
# - MIN(nome_coluna) -> Valor mínimo
# - MAX(nome_coluna) -> Valor máximo
# - COUNT(nome_coluna) -> Contagem

# %%
# Conecte o curso a tabela de transações
query = """
SELECT
    c.curso, 
    SUM(c.valor_curso) AS "acumulado"
FROM ada.transacoes AS t
LEFT JOIN ada.cursos AS c ON t.id_curso = c.id_curso
GROUP BY c.curso
"""

df = pd.read_sql_query(query, con = conn)
df
# Out:
#               curso  acumulado
# 0   arquiteto dados      400.0
# 1     ciencia dados      910.0
# 2     analise dados      400.0
# 3  engenharia dados      480.0

# %%
# Conecte o curso a tabela de transações
# Out:
#               curso  média
# 0   arquiteto dados   80.0
# 1     ciencia dados   70.0
# 2     analise dados   50.0
# 3  engenharia dados   60.0

# %%
# Out:
#               curso  quantidade
# 0   arquiteto dados           5
# 1     ciencia dados          13
# 2     analise dados           8
# 3  engenharia dados           8

# %% [markdown]
# 1) Quantos cursos cada vendedor vendeu?

# %%
# Out:
#    id_vendedor vendedor  quantidade
# 0            1    paulo          14
# 1            2  adriana          13
# 2            3    nadir           7

# %%
# Out:
#    id_vendedor vendedor  quantidade
# 0            1    paulo          14
# 1            2  adriana          13
# 2            3    nadir           7

# %% [markdown]
# 2) Qual o montante vendido por cada vendedor?

# %%
# Out:
#    id_vendedor vendedor  Montante
# 0            1    paulo     860.0
# 1            2  adriana     920.0
# 2            3    nadir     410.0

# %%
# Out:
#    id_vendedor vendedor      Média
# 0            1    paulo  61.428571
# 1            2  adriana  70.769231
# 2            3    nadir  58.571429

# %%
# Out:
#    id_vendedor vendedor  Quantidade      Média  Montante  Mínimo  Máximo
# 0            1    paulo          14  61.428571     860.0    50.0    70.0
# 1            2  adriana          13  70.769231     920.0    60.0    80.0
# 2            3    nadir           7  58.571429     410.0    50.0    70.0

# %% [markdown]
# 3. Quantos de cada curso foi vendido por cada vendedor?

# %%
# Out:
#    id_vendedor vendedor  id_curso             curso  Quantidade
# 0            1    paulo         1  engenharia dados           4
# 1            1    paulo         2     ciencia dados           6
# 2            1    paulo         3     analise dados           4
# 3            2  adriana         1  engenharia dados           4
# 4            2  adriana         2     ciencia dados           4
# 5            2  adriana         4   arquiteto dados           5
# 6            3    nadir         2     ciencia dados           3
# 7            3    nadir         3     analise dados           4

# %% [markdown]
# 4. Qual o montande de cada curso  arrecadado por cada vendedor?

# %%
# Out:
#    id_vendedor vendedor  id_curso             curso  Quantidade  Montante
# 0            1    paulo         1  engenharia dados           4     240.0
# 1            1    paulo         2     ciencia dados           6     420.0
# 2            1    paulo         3     analise dados           4     200.0
# 3            2  adriana         1  engenharia dados           4     240.0
# 4            2  adriana         2     ciencia dados           4     280.0
# 5            2  adriana         4   arquiteto dados           5     400.0
# 6            3    nadir         2     ciencia dados           3     210.0
# 7            3    nadir         3     analise dados           4     200.0

# %%
# Out:
#    id_vendedor vendedor  id_curso            curso  Quantidade  Montante
# 0            1    paulo         2    ciencia dados           6     420.0
# 1            2  adriana         4  arquiteto dados           5     400.0

# %%
# Out:
#    id_vendedor vendedor  id_curso          curso  Quantidade  Montante
# 0            1    paulo         2  ciencia dados           6     420.0

# %% [markdown]
# # Dica "inFAOlível" da ordem das operações na query
#
# - F: Filtra -> WHERE
# - A: Agrega -> GROUP BY
# - O: Ordena -> ORDER BY

# %% [markdown]
# # Exercício 1:
#
# Construa a tabela inicial sem a normalização.

# %%
query = """
SELECT

"""

dd = pd.read_sql_query(query, con = conn)
dd.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Exercício 2:
#
# Realize uma query com a média do recebido por curso

# %% [markdown]
# ### Exercício 3:
#
# Realize uma query que calcule o quanto foi recebido de alunos que começam com a letra A;

# %% [markdown]
# ### Exercício 4:
#
# Realize uma query que calcule quanto foi recebido de cada cidade
#
#
# E se eu quiser ver resultados acima de um valor específico? Como filtro o Group By?

# %% [markdown]
# ### Exercício 5:
#
# Realize uma query que calcule o quanto foi recebido por cada estado.

# %% [markdown]
# ### Exercício 6:
#
# Realize queryes para saber quem trouxe mais dinheiro: pessoas com dois telefones ou com um telefone?

# %% [markdown]
# ### Exercício 7:
#
# Realize uma query para saber qual foi o lucrado total por cada vendedor

# %% [markdown]
# ### Exercício 8:
#
# Realize uma query para saber o valor médio das vendas de cada vendedor

# %% [markdown]
# ### Exercicio 9:
#
# Qual vendedor vendeu mais cursos?

# %% [markdown]
# ### Exercício 10:
#
# Quais os tipos de pagamentos mais usado por cada vendedor?

# %% [markdown]
# ### Exercício 11:
#
# Quais tipos de pagamentos são mais utilizados?

# %% [markdown]
# ### Exercício 12:
#
# Quais pagamentos levantam mais montante de dinheiro?

# %% [markdown]
# ### Exercício 13:
#
# Quais pagamentos apresentam os maiores valores médio?

# %% [markdown]
# ### Exercício 14:
#
# Quais as cidades que cada vendedor atua mais?

# %% [markdown]
# ### Exercício 15:
#
# Qual o curso preferido de cada cidade?

# %% [markdown]
# ### Exercício 16:
#
# Qual o montante mensal recebido?

# %% [markdown]
# ### Exercício 17:
#
# Qual a média mensal recebida?

# %% [markdown]
# ### Exerício 18:
#
# Dos alunos com dois telefones, qual montante levantado por cada tipo de pagamento?

# %% [markdown]
# ### Exercício 19:
#
# Quais os cursos mais frequentes e quais os montates levantados pelos alunos que contém a letra G no nome?

# %% [markdown]
# ### Exercício 20:
#
# Quantos alunos temos por cada cidade? Mais alunos na cidade significa maior montante gerado pela cidade?
